# %% [markdown]
# <a href="https://colab.research.google.com/github/cormac-black/chekhovs-biscuit/blob/main/cv2_tester.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mping



img_path = '/content/headshot.jpg'

image = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)

# image = mping.imread(img_path)

image[:, :, 2] = 0

plt.imshow(image)
plt.axis('off')
print('Image 1\n')
plt.show()
# Out:
# Image 1
