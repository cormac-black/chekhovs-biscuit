# %% [markdown]
# <a href="https://colab.research.google.com/github/cormac-black/chekhovs-biscuit/blob/main/cv2_tester.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mping

img_path = '/content/Images from Colab/headshot.jpg'

image = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
image_h, image_w = image.shape[:2]
print(image_h, image_w)


radians_sine = np.linspace(np.pi/2,2*np.pi+np.pi/2, image_h)
radians_cos = np.linspace(np.pi/2,2*np.pi+np.pi/2, image_w)
slope_tan = np.linspace(-2,2,image_h)

sine_wave = np.sin(radians_sine)
cos_wave = np.cos(radians_cos)
tanh_gradient = np.tanh(slope_tan)




for i in range(image_h):
  for j in range(image_w):



image[:, :, 0] = 0
image[:, :, 1] = 0
image[:, :, 2] = 0

plt.imshow(image)
plt.axis('off')
print('Image 1\n')
plt.show()
# Out:
# [[[0.3584  0.2588  0.06976]
#   [0.3584  0.2588  0.06976]
#   [0.3584  0.2588  0.0349 ]
#   ...
#   [0.6294  0.515   0.1392 ]
#   [0.6294  0.515   0.1392 ]
#   [0.6294  0.515   0.1392 ]]
#
#  [[0.3584  0.2588  0.06976]
#   [0.3584  0.2588  0.06976]
#   [0.3748  0.2756  0.05234]
#   ...
#   [0.643   0.53    0.1565 ]
#   [0.6294  0.515   0.1392 ]
#   [0.6294  0.515   0.1392 ]]
#
#  [[0.3584  0.2588  0.0349 ]
#   [0.3748  0.2756  0.05234]
#   [0.3906  0.2922  0.06976]
#   ...
#   [0.643   0.53    0.1565 ]
#   [0.6294  0.515   0.1392 ]
#   [0.6294  0.515   0.1392 ]]
#
#  ...
#
#  [[0.05234 0.05234 0.05234]
#   [0.05234 0.05234 0.05234]
#   [0.05234 0.05234 0.05234]
#   ...
#   [0.309   0.309   0.309  ]
#   [0.242   0.242   0.242  ]
#   [0.2588  0.2588  0.2588 ]]
#
#  [[0.05234 0.05234 0.05234]
#   [0.05234 0.05234 0.05234]
#   [0.05234 0.05234 0.05234]
#   ...
#   [0.1565  0.1565  0.1565 ]
#   [0.2588  0.2588  0.2588 ]
#   [0.3254  0.3254  0.3254 ]]
#
#  [[0.0349  0.0349  0.0349 ]
# ...
